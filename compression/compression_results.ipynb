# %%
import os

fn = "20_hmm.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 13336 bytes, 106688 bits

# %%
import os

fn = "20_mc.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 13336 bytes, 106688 bits

# %%
import os

fn = "30_hmm.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 13334 bytes, 106672 bits

# %%
import os

fn = "30_mc.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 13381 bytes, 107048 bits

# %%
import os

fn = "40_hmm.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 13336 bytes, 106688 bits

# %%
import os

fn = "40_mc.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 13334 bytes, 106672 bits

# %%
import os

fn = "20_hmm_1m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 105936 bytes, 847488 bits

# %%
import os

fn = "20_mc_1m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 125954 bytes, 1007632 bits

# %%
import os

fn = "20_mc_10m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 1252038 bytes, 10016304 bits

# %%
import os

fn = "30_mc_1m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 125889 bytes, 1007112 bits

# %%
import os

fn = "30_mc_10m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 1251337 bytes, 10010696 bits

# %%
import os

fn = "40_mc_1m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 125885 bytes, 1007080 bits

# %%
import os

fn = "40_mc_10m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 1251339 bytes, 10010712 bits

# %%
import os

fn = "40_hmm_1m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 125953 bytes, 1007624 bits

# %%
import os

fn = "40_hmm_10m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 1251284 bytes, 10010272 bits

# %%
import os

fn = "30_hmm_1m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 106237 bytes, 849896 bits

# %%
import os

fn = "30_hmm_10m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 974944 bytes, 7799552 bits

# %%
import os

fn = "20_hmm_10m.dzip.combined"
size_bytes = os.path.getsize(fn)
size_bits  = size_bytes * 8

print(f"Compressed size: {size_bytes} bytes, {size_bits} bits")
# Out:
# Compressed size: 975501 bytes, 7804008 bits
